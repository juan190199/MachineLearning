# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

from pca import pca
from viz import plot_figure

# %load_ext autoreload
# %autoreload 2

# %%
data = load_iris()
X = data.data
y = data.target

data_2d = pca(X, 2)

# %%
sklearn_pca = PCA(n_components=2)
sklearn_data_2d = sklearn_pca.fit_transform(X)

# %%
plot_figure(data_2d, y, sklearn_data_2d)
